# %% [markdown]
# <a href="https://colab.research.google.com/github/suspenseful3day/sun2/blob/main/%EC%84%A0%EB%8C%80%EC%88%98_%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import torch
import torch.optim as optim
import matplotlib.pyplot as plt

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-6d26fdea-7424-4b4d-a79a-925ef3108db9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6d26fdea-7424-4b4d-a79a-925ef3108db9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
nrow, ncol = df.shape

# %%
print("Iris data set :", nrow, "records with", ncol, "attributes\n" )
print("First 5 records in iris data\n", df.head(5))
# Out:
# Iris data set : 150 records with 6 attributes
#
# First 5 records in iris data
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
X1 = df[['SepalLengthCm']]
X2 = df[['SepalWidthCm']]
X3 = df[['PetalLengthCm']]
X4 = df[['PetalWidthCm']]
Y = df[['Species']]

# %%
m=len(df)
X1=(np.array(X1)).reshape(m,1)
X2=(np.array(X2)).reshape(m,1)
X3=(np.array(X3)).reshape(m,1)
X4=(np.array(X4)).reshape(m,1)
Y=(np.array(Y)).reshape(m,1)

# %%
Y = np.array(Y)
x0=np.ones((m,1))
Xb=np.c_[x0,X1,X2,X3,X4]
W = torch.zeros(1, requires_grad=True)
b = torch.zeros(1, requires_grad=True)

# %%
Xb = torch.from_numpy(Xb)
hypothesis = Xb*W + b
cost = torch.mean((hypothesis - Y)**2)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-41-710a20d525c1> in <cell line: 3>()
#       1 Xb = torch.from_numpy(Xb)
#       2 hypothesis = Xb*W + b
# ----> 3 cost = torch.mean((hypothesis - Y)**2)
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py in __array__(self, dtype)
#    1060             return handle_torch_function(Tensor.__array__, (self,), self, dtype=dtype)
#    1061         if dtype is None:
# -> 1062             return self.numpy()
#    1063         else:
#    1064             return self.numpy().astype(dtype, copy=False)
#
# RuntimeError: Can't call numpy() on Tensor that requires grad. Use tensor.detach().numpy() instead.
