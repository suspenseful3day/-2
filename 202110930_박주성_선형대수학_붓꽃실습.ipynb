# %% [markdown]
# <a href="https://colab.research.google.com/github/suspenseful3day/sun2/blob/main/202110930_%EB%B0%95%EC%A3%BC%EC%84%B1_%EC%84%A0%ED%98%95%EB%8C%80%EC%88%98%ED%95%99_%EB%B6%93%EA%BD%83%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import pandas as pd
from sklearn.preprocessing import StandardScaler
from google.colab import drive

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-f4901c83-bdd2-4e09-80f1-3ea1d7071e23" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f4901c83-bdd2-4e09-80f1-3ea1d7071e23">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
nrow, ncol = df.shape

# %%
print("Iris data set :", nrow, "records with", ncol, "attributes\n" )
print("First 5 records in iris data\n", df.head(5))
# Out:
# Iris data set : 151 records with 5 attributes
#
# First 5 records in iris data
#       sepal length   sepal width   petal length   petal width       target
# Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa

# %%
features = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']
x = df.loc[:, features].values
y = df.loc[:,['Species']].values
x = StandardScaler().fit_transform(x)

# %%
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x)

# %%
print("\nFirst principal axis:",pca.components_[0])
print("Second principal axis:",pca.components_[1])
# Out:
# First principal axis: [ 0.52237162 -0.26335492  0.58125401  0.56561105]
# Second principal axis: [0.37231836 0.92555649 0.02109478 0.06541577]

# %%
principalDf = pd.DataFrame(data = principalComponents,
                           columns = ['principal component 1','principal component 2'])
finalDf = pd.concat([principalDf, df[['Species']]], axis = 1)

# %%
print(finalDf.head)
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1,1,1)
ax.set_xlabel('principal component 1', fontsize = 12)
ax.set_ylabel('principal component 2', fontsize = 12)
ax.set_title('PCA with 2 components', fontsize = 15)
# Out:
# <bound method NDFrame.head of      principal component 1  principal component 2         Species
# 0                -2.264542               0.505704     Iris-setosa
# 1                -2.086426              -0.655405     Iris-setosa
# 2                -2.367950              -0.318477     Iris-setosa
# 3                -2.304197              -0.575368     Iris-setosa
# 4                -2.388777               0.674767     Iris-setosa
# ..                     ...                    ...             ...
# 145               1.870522               0.382822  Iris-virginica
# 146               1.558492              -0.905314  Iris-virginica
# 147               1.520845               0.266795  Iris-virginica
# 148               1.376391               1.016362  Iris-virginica
# 149               0.959299              -0.022284  Iris-virginica
#
# [150 rows x 3 columns]>
# Text(0.5, 1.0, 'PCA with 2 components')

# %%
Spieces_ = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
colors = ['r','g','b']
for Spieces, color in zip(Spieces_, colors):
  indicesToKeep = finalDf['Species'] == Spieces
  ax.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
             , finalDf.loc[indicesToKeep, 'principal component 2'],c = color, s=40)
ax.legend(Spieces_)
ax.grid()
fig.show()
