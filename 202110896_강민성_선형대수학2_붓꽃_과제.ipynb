# %% [markdown]
# <a href="https://colab.research.google.com/github/suspenseful3day/sun2/blob/main/202110896_%EA%B0%95%EB%AF%BC%EC%84%B1_%EC%84%A0%ED%98%95%EB%8C%80%EC%88%98%ED%95%992_%EB%B6%93%EA%BD%83_%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

filename = '/content/drive/MyDrive/Iris.csv'

data = pd.read_csv(filename)
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
from sklearn.datasets import load_iris
iris = load_iris()
iris.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import matplotlib.pyplot as plt

# 붓꽃 데이터셋 로드
iris = load_iris()
X = iris.data
y = iris.target

# 원-핫 인코딩
encoder = OneHotEncoder(sparse=False)
y = encoder.fit_transform(y.reshape(-1, 1))

# 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=100, random_state=42)

# 모델 설계
model = Sequential([
    Dense(10, input_shape=(4,), activation='relu'),
    Dense(10, activation='relu'),
    Dense(3, activation='softmax')
])

# 모델 컴파일
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# 모델 훈련
history = model.fit(X_train, y_train, epochs=1000, batch_size=100, verbose=1, validation_data=(X_test, y_test))

# 훈련과 검증 정확도 그래프 그리기
plt.plot(history.history['val_accuracy'])
plt.xlabel('Iteration number')
plt.ylabel('Accuracy')
plt.xticks([0, 250, 500, 750,1000])
plt.title('Accuracy')
plt.show()
# Out:
# Epoch 1/1000
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# 1/1 [==============================] - 1s 926ms/step - loss: 1.6114 - accuracy: 0.2600 - val_loss: 1.4791 - val_accuracy: 0.3500
# Epoch 2/1000
# 1/1 [==============================] - 0s 51ms/step - loss: 1.5941 - accuracy: 0.2600 - val_loss: 1.4644 - val_accuracy: 0.3500
# Epoch 3/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 1.5771 - accuracy: 0.2600 - val_loss: 1.4500 - val_accuracy: 0.3500
# Epoch 4/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 1.5604 - accuracy: 0.2600 - val_loss: 1.4358 - val_accuracy: 0.3500
# Epoch 5/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 1.5442 - accuracy: 0.2600 - val_loss: 1.4218 - val_accuracy: 0.3500
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import matplotlib.pyplot as plt

# 붓꽃 데이터셋 로드
iris = load_iris()
X = iris.data
y = iris.target

# 원-핫 인코딩
encoder = OneHotEncoder(sparse=False)
y = encoder.fit_transform(y.reshape(-1, 1))

# 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=100, random_state=42)

# 모델 설계
model = Sequential([
    Dense(10, input_shape=(4,), activation='relu'),
    Dense(10, activation='relu'),
    Dense(3, activation='softmax')
])

# 모델 컴파일
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# 모델 훈련
history = model.fit(X_train, y_train, epochs=1000, batch_size=100, verbose=1, validation_data=(X_test, y_test))

# 훈련과 검증 손실 그래프 그리기
plt.plot(history.history['val_loss'])
plt.xlabel('Iteration Number')
plt.ylabel('Average Cost')
plt.xticks([0, 250, 500, 750,1000])
plt.title('Average Cost')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Epoch 1/1000
# 1/1 [==============================] - 2s 2s/step - loss: 5.0348 - accuracy: 0.2600 - val_loss: 4.3027 - val_accuracy: 0.3700
# Epoch 2/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 4.9771 - accuracy: 0.2600 - val_loss: 4.2547 - val_accuracy: 0.3700
# Epoch 3/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 4.9200 - accuracy: 0.2600 - val_loss: 4.2071 - val_accuracy: 0.3700
# Epoch 4/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 4.8633 - accuracy: 0.2600 - val_loss: 4.1600 - val_accuracy: 0.3700
# Epoch 5/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 4.8072 - accuracy: 0.2600 - val_loss: 4.1134 - val_accuracy: 0.3700
# ...
